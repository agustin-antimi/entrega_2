# %% [markdown]
# # Ejercicio 5
#
# ## Calculadora de costo de envío
#
# Calcule el costo de envío de un paquete según su peso (en kg) y la zona de
# destino. El usuario debe ingresar ambos valores.
#
# Las zonas válidas son: local, regional, nacional.
#
# |Peso / Zona | Local | Regional | Nacional|
# |---------------|-------|-------|------|
# |Hasta 1 kg     | $500  | $1000 | $2000|
# |Entre 1 y 5 kg | $1000 | $2500 | $4500|
# |Más de 5 kg    | $2000 | $5000 | $8000|
#
# Si la zona no es válida, debe indicar el error.

# %% [markdown]
# ### Primero importamos las funciones desde nuestro archivo `src/functions_05.py`
# Para lo cual utilizaremos el modulo `sys` y `os`, los cuales nos permiten poder importar carpetas de jerarquia mayor a la que estamos parados.

# %%
import os
import sys

# Subimos un nivel en las carpetas para que Python encuentre src
sys.path.append(os.path.abspath('..'))
print("ACCESO A DIRECTORIOS DE MAYOR JERARQUIA")
# Out:
# ACCESO A DIRECTORIOS DE MAYOR JERARQUIA

# %%
# Importamos las funciones 
import src.functions_05 as fn
print("FUNCIONES DEL ARCHIVO [functions_05.py] IMPORTADAS CON EXITO")
# Out:
# FUNCIONES DEL ARCHIVO [functions_05.py] IMPORTADAS CON EXITO

# %% [markdown]
# ### Calculadora de costo de envio.
#
# tenemos una funcion que permite la interaccion con el usuario. O sino podemos usar su funcion auxilar la cual nos permite calcular un precio de envio, pasandole dos parametros.
#
# #### Funcion con interaccion de usuario

# %%
fn.calculadora_precio_envio()
# Out:
# --- Calculadora de Costo de Envio ---
# El costo de envio para un paquete de 2.0kg a la zona local es de $1000

# %% [markdown]
# #### Funcion auxiliar que solo calcula costo.

# %%
peso = 5
zona = "Nacional"

precio = fn.calcular_costo_envio(peso, zona)
precio
# Out:
# 'El costo de envio para un paquete de 5kg a la zona nacional es de $4500'
