# %% [markdown]
# # 3. ejercicio
#
# ## Filtro de spoilers
#
# ### Dada la siguiente reseña de una película:
# ```py
# review = """La película sigue a un grupo de astronautas que
# viajan a Marte
# en una misión de rescate. El capitán Torres lidera al equipo
# a través
# de tormentas solares y fallos en el sistema de navegación. Al
# llegar
# a Marte descubren que la base está abandonada y los
# suministros
# destruidos. Torres decide sacrificar la nave nodriza para
# salvar
# al equipo y logran volver a la Tierra en una cápsula de
# emergencia.
# El final revela que Torres sobrevivió gracias a un pasaje
# secreto."""
# ```
#
# Solicite al usuario una lista de palabras consideradas spoilers (separadas por
# coma). El programa debe reemplazar todas las apariciones de esas palabras en el
# texto por asteriscos (*) de la misma longitud, sin distinguir mayúsculas de
# minúsculas.

# %% [markdown]
# ### Primero importamos las funciones desde nuestro archivo `src/functions_03.py`
# Para lo cual utilizaremos el modulo `sys` y `os`, los cuales nos permiten poder importar carpetas de jerarquia mayor a la que estamos parados.

# %%
import os
import sys

# Subimos un nivel en las carpetas para que Python encuentre src
sys.path.append(os.path.abspath('..'))
print("ACCESO A DIRECTORIOS DE MAYOR JERARQUIA")
# Out:
# ACCESO A DIRECTORIOS DE MAYOR JERARQUIA

# %%
# Importamos las funciones 
import src.functions_03 as fn
print("FUNCIONES DEL ARCHIVO [functions_03.py] IMPORTADAS CON EXITO")
# Out:
# FUNCIONES DEL ARCHIVO [functions_03.py] IMPORTADAS CON EXITO

# %%
review = """La película sigue a un grupo de astronautas que
viajan a Marte
en una misión de rescate. El capitán Torres lidera al equipo
a través
de tormentas solares y fallos en el sistema de navegación. Al
llegar
a Marte descubren que la base está abandonada y los
suministros
destruidos. Torres decide sacrificar la nave nodriza para
salvar
al equipo y logran volver a la Tierra en una cápsula de
emergencia.
El final revela que Torres sobrevivió gracias a un pasaje
secreto."""

# %% [markdown]
# ### Filtro
#
# Utilizaremos la funcion `remplazar_spoilers()`, donde le pasaremos la lista de spoilers separados por coma, y el texto a censurar.

# %%
# Importamos dependencia para darle formato al texto
import textwrap

lista_de_spoilers = input("Ingrese las palabras a censurar separadas por coma")
review_sin_spoilers = fn.remplazar_spoilers(lista_de_spoilers, review)

print(f"PALABRAS INGRESADAS COMO SPOILERS: {lista_de_spoilers}\n")
print(f"REVIEW SIN SPOILERS:\n{textwrap.fill(review_sin_spoilers, width=60)}")
# Out:
# PALABRAS INGRESADAS COMO SPOILERS: Marte, Torres, Sacrificar, Sobrevivió
#
# REVIEW SIN SPOILERS:
# La película sigue a un grupo de astronautas que viajan a
# ***** en una misión de rescate. El capitán ****** lidera al
# equipo a través de tormentas solares y fallos en el sistema
# de navegación. Al llegar a ***** descubren que la base está
# abandonada y los suministros destruidos. ****** decide
# ********** la nave nodriza para salvar al equipo y logran
# volver a la Tierra en una cápsula de emergencia. El final
# revela que ****** ********** gracias a un pasaje secreto.
