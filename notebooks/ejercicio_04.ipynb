# %% [markdown]
# # 4. Ejercico
#
# ## Validación de email
#
# ### Valide una dirección de email ingresada por el usuario con los siguientes
# criterios:
#
# - Contiene exactamente un @.
# - Tiene al menos un carácter antes del @.
# - Tiene al menos un punto (.) después del @.
# - No empieza ni termina con @ ni con ..
# - La parte después del último punto tiene al menos 2 caracteres (el dominio).

# %% [markdown]
# ### Primero importamos las funciones desde nuestro archivo `src/functions_04.py`
# Para lo cual utilizaremos el modulo `sys` y `os`, los cuales nos permiten poder importar carpetas de jerarquia mayor a la que estamos parados.

# %%
import os
import sys

# Subimos un nivel en las carpetas para que Python encuentre src
sys.path.append(os.path.abspath('..'))
print("ACCESO A DIRECTORIOS DE MAYOR JERARQUIA")
# Out:
# ACCESO A DIRECTORIOS DE MAYOR JERARQUIA

# %%
# Importamos las funciones 
import src.functions_04 as fn
print("FUNCIONES DEL ARCHIVO [functions_04.py] IMPORTADAS CON EXITO")
# Out:
# FUNCIONES DEL ARCHIVO [functions_04.py] IMPORTADAS CON EXITO

# %% [markdown]
# #### Validaciond de mail
#
# Utilizaremos la funcion `validar_mail()`, del modulo src/functions_04.py.

# %%
email = input("Ingrese un mail: ")
print(f"EMAIL INGRESADO: {email}")

if fn.validar_email(email):
    print("El email es valido")
else:
    print("El email no es valido")
# Out:
# EMAIL INGRESADO: usuario@ejemplo.com
# El email es valido
